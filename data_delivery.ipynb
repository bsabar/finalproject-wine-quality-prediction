# %%
import pandas as pd
from pathlib import Path

# %%
# File to Load (Remember to Change These)
wine_red_data_to_load = Path("Resources/wine+quality/winequality-red.csv")
wine_white_data_to_load = Path("Resources/wine+quality/winequality-white.csv")

# %%
# Read Wine_Red_Data and Wine_Red_Data File and store into Pandas DataFrames
wine_red_data = pd.read_csv(wine_red_data_to_load, delimiter=';')
wine_white_data = pd.read_csv(wine_white_data_to_load, delimiter=';')

# %%
wine_red_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine_red_data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wine_red_data["color"] = 'red'

# %%
wine_red_data["color"]
# Out:
# 0       red
# 1       red
# 2       red
# 3       red
# 4       red
#        ...
# 1594    red
# 1595    red
# 1596    red
# 1597    red
# 1598    red
# Name: color, Length: 1599, dtype: object

# %%
wine_white_data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wine_white_data["color"] = 'white'

# %%
wine_white_data["color"]
# Out:
# 0       white
# 1       white
# 2       white
# 3       white
# 4       white
#         ...
# 4893    white
# 4894    white
# 4895    white
# 4896    white
# 4897    white
# Name: color, Length: 4898, dtype: object

# %%
wine_complete = pd.concat([wine_red_data, wine_white_data])

# %%
wine_complete.shape
# Out:
# (6497, 13)

# %%
wine_complete.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4514            6.1              0.40         0.18             9.0      0.051
# 2372            6.0              0.33         0.18             3.0      0.036
# 1029            6.3              0.60         0.44            11.0      0.050
# 271            11.5              0.18         0.51             4.0      0.104
# 131             5.6              0.50         0.09             2.3      0.049
# 230             5.2              0.48         0.04             1.6      0.054
# 2247            6.1              0.15         0.29             6.2      0.046
# 218             7.5              0.49         0.19             1.9      0.076
# 611             7.4              0.24         0.40             4.3      0.032
# 3498            6.4              0.30         0.36             2.0      0.052
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4514                 28.5                 259.0  0.99640  3.19       0.50
# 2372                  5.0                  85.0  0.99125  3.28       0.40
# 1029                 50.0                 245.0  0.99720  3.19       0.57
# 271                   4.0                  23.0  0.99960  3.28       0.97
# 131                  17.0                  99.0  0.99370  3.63       0.63
# 230                  19.0                 106.0  0.99270  3.54       0.62
# 2247                 39.0                 151.0  0.99471  3.60       0.44
# 218                  10.0                  44.0  0.99570  3.39       0.54
# 611                   9.0                  95.0  0.99200  3.09       0.39
# 3498                 18.0                 141.0  0.99273  3.38       0.53
#
#       alcohol  quality  color
# 4514      8.8        5  white
# 2372     11.5        4  white
# 1029      9.3        4  white
# 271      10.1        6    red
# 131      13.0        5    red
# 230      12.2        7    red
# 2247     10.6        6  white
# 218       9.7        5    red
# 611      11.1        6  white
# 3498     10.5        6  white

# %%
pd.get_dummies(wine_complete)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color_red  color_white
# 0         9.4        5       True        False
# 1         9.8        5       True        False
# 2         9.8        5       True        False
# 3         9.8        6       True        False
# 4         9.4        5       True        False
# ...       ...      ...        ...          ...
# 4893     11.2        6      False         True
# 4894      9.6        5      False         True
# 4895      9.4        6      False         True
# 4896     12.8        7      False         True
# 4897     11.8        6      False         True
#
# [6497 rows x 14 columns]

# %%
wine_complete.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64
